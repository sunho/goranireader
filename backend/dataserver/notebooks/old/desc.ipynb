# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/sunho/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import pandas as pd

df = pd.read_csv('data.csv')

# %%
from nltk.corpus import stopwords

# %%
df2 = df[~df['word'].isin(stopwords.words("english"))]

# %%
df2['word'].value_counts()
# Out:
# jade            2604
# would           1064
# one              887
# willow           867
# could            791
#                 ...
# diminished         1
# arrangements       1
# vibrance           1
# follower           1
# locks              1
# Name: word, Length: 5804, dtype: int64

# %%
df2['signal'].hist()
