# %%
from gorani.booky.book import Book, read_epub

# %%
from metaflow import Flow
import numpy as np
import pandas as pd

# %%
run = Flow('MergeFilterPaginate').latest_successful_run
df = run.data.pages

# %%
df = df.loc[df['userId'] == '8ACCQYz8NMc4Lc9Nze3R']

# %%
df['i'] = np.arange(len(df))
df['signalWord'] = df.apply(lambda x: [[x['words'][i].lower(), 0 if (i in x['unknownIndices']) or (x['words'][i].lower() in [y.lower() for y in x['unknownWords']]) else 1] for i in range(len(x['words']))], axis = 1)

# %%
def handle(value):
    words = []
    knows = []
    times = []
    for x, t in zip(value['signalWord'], value['time']):
        for y in x:
            if len(y) != 2:
                continue    
            words.append(y[0])
            knows.append(y[1])
            times.append(t)
    return pd.DataFrame({'word': words, 'known': knows, 'time': times}).reset_index()
df3 = df.groupby(['userId']).apply(handle).reset_index(level=1, drop=True).reset_index()
df3.set_index(['userId','word'], inplace=True)
df3 = df3.sort_values(['time'])

# %%
def retention(df):
    count = 0
    start = 0
    total = 0
    days = []
    maxDay = 0
    
    for t, k in zip(df['time'], df['known']):
        if start == 0:
            start = t
        dur = t - start
        total += k
        count += 1
        tmp = int(dur/(60*60))
        days.append({'day': tmp, 'known': k})
        if maxDay < tmp:
            maxDay = tmp
    df = pd.DataFrame(days).groupby('day').mean().reset_index()
    if df.size >=2:
        first = df.iloc[0]['known']
        last = df.iloc[-1]['known']
    else:
        first = np.nan
        last = np.nan
    return pd.Series({'count': count, 'days': maxDay + 1, 'avg': total/count, 'first': first, 'last': last, 'df': df})

df4 = df3.groupby(['userId','word']).apply(retention)

# %%
books = dict()

# %%
book = read_epub(os.path.join('../books', 'rezero10.epub'))
# Out:
# [nltk_data] Downloading package punkt to /Users/sunho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ../images/00001.jpg
# ../images/00002.jpg
# ../images/00003.jpg
# ../images/00004.jpg
# ../images/00005.jpg
# ../images/00006.jpg
# ../images/00007.jpg
# ../images/00010.jpeg
# ../images/00011.jpeg
# ../images/00012.jpeg
# ../images/00013.jpeg
# ../images/00014.jpeg
# ../images/00015.jpeg
# ../images/00016.jpeg
# ../images/00017.jpeg
# ../images/00018.jpeg
# ../images/00019.jpeg
# ../images/00020.jpeg
# ../images/00021.jpeg

# %%
from gorani.utils import split_sentence
words = [split_sentence(item.content) for chap in book.chapters for item in chap.items if item.kind == 'sentence']
words = [item.lower() for sublist in words for item in sublist]
with open("words.txt", "w") as outfile:
    outfile.write("\n".join(pd.Series(words).unique().tolist()))

# %%
import os
for filename in os.listdir('../books'):
    if filename not in books:
        book = read_epub(os.path.join('../books', filename))
        books[filename] = book
# Out:
# [nltk_data] Downloading package punkt to /Users/sunho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# images/Art_2mdash.jpg ……
# images/Art_sborn.jpg
# images/Art_P127.jpg
# images/Art_sborn.jpg
# images/Art_2mdash.jpg ……Sora, though he’d just been charging under the assumption it was porn—along with everyone else, all present, somehow—was struck dumb.
# images/Art_cnorn.jpg CHAPTER 4
# images/Art_sborn.jpg
# images/Art_sborn.jpg
# images/Art_P146.jpg
# images/Art_sborn.jpg
# images/Art_sborn.jpg
# images/Art_3mdash.jpg They were insane. It was not appropriate to describe these siblings by oblique expressions such as “unsound” or “unhinged.” Correctly. Truly. In the literal sense—they were insane .
# images/Art_P162.jpg
# images/Art_cnorn.jpg FAKE END
# images/Art_sborn.jpg
# images/Art_2mdash.jpg ……
# images/Art_2mdash.jpg Then. Steph’s words finally made it into Shiro’s ears. What was—Steph saying? Shiro only had one brother . Shiro took out her phone and opened her contact list—but.
# images/Art_2mdash.jpg Please. Let this be only a terrible, awful dream . Let me wake up and find my brother sleeping there as always. Let him just tell me—“Good morning.” That was all she wished for as she surrendered herself to the darkness that overcame her.
# images/Art_P174.jpg
# images/Art_cnorn.jpg AFTERWORD
# images/Art_P180.jpg
# images/Art_P181.jpg
# images/Art_P184.jpg
# images/Art_P185.jpg
# images/Art_cnorn.jpg TRANSLATION NOTES
# [nltk_data] Downloading package punkt to /Users/sunho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ../Images/image00277.jpeg
# ../Images/image00278.jpeg
# ../Images/image00279.jpeg
# ../Images/image00280.jpeg
# ../Images/image00281.jpeg
# ../Images/image00282.jpeg
# ../Images/image00283.jpeg
# ../Images/image00284.jpeg
# ../Images/image00285.jpeg
# ../Images/image00286.jpeg
# ../Images/image00287.jpeg
# ../Images/image00288.jpeg
# ../Images/image00289.jpeg
# ../Images/image00290.jpeg
# ../Images/image00291.jpeg
# ../Images/image00292.jpeg
# ../Images/image00293.jpeg
# ../Images/image00294.jpeg
# ../Images/image00295.jpeg
# [nltk_data] Downloading package punkt to /Users/sunho/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ../Images/crown.jpg Prologue
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3ff42fa969c8> in <module>
#       2 for filename in os.listdir('../books'):
#       3     if filename not in books:
# ----> 4         book = read_epub(os.path.join('../books', filename))
#       5         books[filename] = book
#
# ~/Documents/dev/gorani-reader/backend/dataserver/gorani/gorani/booky/book.py in read_epub(path)
#      13     from .epub_converter import convert_epub
#      14     book = epub.read_epub(path)
# ---> 15     return Book(*convert_epub(book))
#      16
#      17 class Item:
#
# ~/Documents/dev/gorani-reader/backend/dataserver/gorani/gorani/booky/epub_converter.py in convert_epub(book)
#      45     author = book.get_metadata('DC', 'creator')[0][0]
#      46     meta = Metadata(0, title, cover, author, coverType)
# ---> 47     return meta, _book_to_chapters(book)
#      48
#      49 def _get_item_by_href(book, href:str):
#
# ~/Documents/dev/gorani-reader/backend/dataserver/gorani/gorani/booky/epub_converter.py in _book_to_chapters(book)
#     102     out = list()
#     103     for content in contents:
# --> 104         content['items'] = _content_to_items(book, content['content'])
#     105         if 'chapter' not in content:
#     106             content['chapter'] = None
#
# ~/Documents/dev/gorani-reader/backend/dataserver/gorani/gorani/booky/epub_converter.py in _content_to_items(book, content)
#     120             item = _get_item_by_href(book, sen)
#     121             print(sen)
# --> 122             imageType = mimetypes.guess_type(item.file_name)[0]
#     123             image = base64.b64encode(item.get_content()).decode('utf-8')
#     124             out.append(Image(str(uuid.uuid1()), image, imageType))
#
# AttributeError: 'NoneType' object has no attribute 'file_name'

# %%
wordset = set(df4.loc[df4['last'] == 1].reset_index()['word'])
wordset2 = set(df4.loc[df4['last'] == 0].reset_index()['word'])

# %%
out = []
for book in books.values():
    out.append({'title':book.meta.title, 'percent':(1-book.compare_by_wordset(wordset)) + (1-book.compare_by_wordset(wordset2))})
pd.DataFrame(out).sort_values('percent', ascending=False)
# Out:
#                                                 title   percent
# 7   I Saved Too Many Girls and Caused the Apocalyp...  0.470164
# 29  If It’s for My Daughter, I’d Even Defeat a Dem...  0.436648
# 25       Tokyo Ghoul: Days: Days (Tokyo Ghoul Novels)  0.433069
# 10               The Rising of the Shield Hero Vol 01  0.416792
# 16   Re:ZERO -Starting Life in Another World-, Vol. 1  0.400310
# 22  Konosuba: God’s Blessing on This Wonderful Wor...  0.392650
# 27           How NOT to Summon a Demon Lord: Volume 1  0.390339
# 13                    Toradora! Light Novel: Volume 1  0.387128
# 8   The Asterisk War, Vol. 1: Encounter with a Fie...  0.385859
# 24  Is It Wrong to Try to Pick Up Girls in a Dungeon?  0.381662
# 26                         Wolf & Parchment, Volume 1  0.373701
# 4   I’ve Been Killing Slimes for 300 Years and Max...  0.373071
# 11                             Spice and Wolf, Vol. 1  0.372974
# 15         Accel World, Vol. 1: Kuroyukihime’s Return  0.369601
# 23                         Durarara!!, Vol. 1 (novel)  0.365533
# 12                               The Rolling Bootlegs  0.363805
# 28  Is It Wrong to Try to Pick Up Girls in a Dunge...  0.358999
# 17                            No Game No Life, Vol. 2  0.357040
# 30  Is It Wrong to Try to Pick Up Girls in a Dunge...  0.353647
# 9                            Strike the Blood, Vol. 1  0.353293
# 6                          Outbreak Company: Volume 1  0.349281
# 18  Didn't I Say to Make My Abilities Average in t...  0.344940
# 5       Black Bullet, Vol. 1: Those Who Would Be Gods  0.342679
# 1                   Overlord, Vol. 1: The Undead King  0.339163
# 14  Death March to the Parallel World Rhapsody - V...  0.338150
# 19  Sword Art Online Alternative Gun Gale Online, ...  0.337496
# 31  My Youth Romantic Comedy Is Wrong, As I Expect...  0.331673
# 0                         Sword Art Online 1: Aincrad  0.330666
# 2    How a Realist Hero Rebuilt the Kingdom: Volume 1  0.324108
# 21                         Clockwork Planet: Volume 1  0.320693
# 20  Arifureta: From Commonplace to World's Stronge...  0.310952
# 3            Sword Art Online Progressive - Volume 01  0.297806
